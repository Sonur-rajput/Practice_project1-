# %% [markdown]
# import all the required library

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# Now load the winequality-red dataset

# %%
data=pd.read_csv('winequality-red.csv')

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
data.shape
# Out:
# (1599, 12)

# %% [markdown]
# All the input variable shown in the dataset are continuous data
#
# Output variable (based on sensory data): 12 - quality (score between 0 and 10) -- Discrete Data
#
# Number of Rows = 1599 and Number of columns = 12

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# we have find that the data is not having null value, we can proceed for next step

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# we can see all the input values are float type and the output is intiger type

# %%
sns.countplot(data['quality'])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %% [markdown]
# Count plot indicates, data is imbalanced as the value count of 5 and 6 is vary large as compared to other quality score.
#
# To make the data balanced we will use upsampling.

# %%
data.nunique()
# Out:
# fixed acidity            96
# volatile acidity        143
# citric acid              80
# residual sugar           91
# chlorides               153
# free sulfur dioxide      60
# total sulfur dioxide    144
# density                 436
# pH                       89
# sulphates                96
# alcohol                  65
# quality                   6
# dtype: int64

# %% [markdown]
# # Bivariate Analysis of the Dataset

# %%
sns.scatterplot(data=data, x="fixed acidity", y="quality", hue="quality")
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='quality'>

# %%
sns.scatterplot(data=data, x="fixed acidity", y="quality", hue="quality")
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='quality'>

# %%
sns.scatterplot(data=data, x="volatile acidity", y="quality", hue="quality")
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='quality'>

# %%
sns.scatterplot(data=data, x="citric acid", y="quality", hue="quality")
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='quality'>

# %%
sns.scatterplot(data=data, x="residual sugar", y="quality", hue="quality")
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='quality'>

# %%
sns.scatterplot(data=data, x="chlorides", y="quality", hue="quality")
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='quality'>

# %%
sns.scatterplot(data=data, x="free sulfur dioxide", y="quality", hue="quality")
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='quality'>

# %%
sns.scatterplot(data=data, x="total sulfur dioxide", y="quality", hue="quality")
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='quality'>

# %%
sns.scatterplot(data=data, x="density", y="quality", hue="quality")
# Out:
# <AxesSubplot:xlabel='density', ylabel='quality'>

# %%
sns.scatterplot(data=data, x="pH", y="quality", hue="quality")
# Out:
# <AxesSubplot:xlabel='pH', ylabel='quality'>

# %%
sns.scatterplot(data=data, x="sulphates", y="quality", hue="quality")
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='quality'>

# %%
sns.scatterplot(data=data, x="alcohol", y="quality", hue="quality")
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='quality'>

# %%
x=data.iloc[:,0:-1]
y=data.iloc[:,-1]

# %%
y.shape
# Out:
# (1599,)

# %%
x.shape
# Out:
# (1599, 11)

# %%
plt.figure(figsize=(20,20), facecolor='skyblue')
plotnumber= 1

for column in x:
    if plotnumber<=14:
        ax= plt.subplot(4,3, plotnumber)
        sns.scatterplot(x[column], y, hue=y)
        plt.xlabel(column, fontsize= 20)
        plt.ylabel('quality', fontsize= 20)
    plotnumber+=1
plt.tight_layout()

# %%
data.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %%
sns.distplot(data['fixed acidity'])
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='Density'>

# %%
sns.distplot(data['volatile acidity'])
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='Density'>

# %%
sns.distplot(data['citric acid'])
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='Density'>

# %%
sns.distplot(data['residual sugar'])
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='Density'>

# %%
sns.distplot(data['chlorides'])
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='Density'>

# %%
sns.distplot(data['free sulfur dioxide'])
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='Density'>

# %%
sns.distplot(data['total sulfur dioxide'])
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='Density'>

# %%
sns.distplot(data['density'])
# Out:
# <AxesSubplot:xlabel='density', ylabel='Density'>

# %%
sns.distplot(data['pH'])
# Out:
# <AxesSubplot:xlabel='pH', ylabel='Density'>

# %%
sns.distplot(data['sulphates'])
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='Density'>

# %%
sns.distplot(data['alcohol'])
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# we have see The Data is not normalised. The building blocks are out of normalised curve

# %%
plt.figure(figsize=(20,20), facecolor='skyblue')
plotnumber= 1

for column in x:
    if plotnumber<=14:
        ax= plt.subplot(4,3, plotnumber)
        sns.distplot(x[column])
        plt.xlabel(column, fontsize= 20)
        plt.ylabel('quality', fontsize= 20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# # The Normal distribution shows that the data is skewed

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
data.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.124052
# volatile acidity     -0.202288 -0.390558
# citric acid           0.109903  0.226373
# residual sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free sulfur dioxide  -0.069408 -0.050656
# total sulfur dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %%
plt.figure(figsize=(15,7))
sns.heatmap(data.corr(), annot=True,linewidths=1,linecolor='black',fmt=' .2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# As we can see alchol,sulphates, citric acid are show the positive co-rellation with quality
#
# and volatile acidity show the negative co-rellation with quality

# %%
collist=data.columns.values
Ncolumns= 10
Nrows= 10

plt.figure(figsize=(Ncolumns,3*Ncolumns))
for i in range(0,len(collist)):
    plt.subplot(Nrows, Ncolumns, i+1)
    sns.boxplot(y=data[collist[i]], color='green', orient='x')
    plt.tight_layout()

# %% [markdown]
#  The data is having outliers

# %% [markdown]
# Now removing Outliers

# %%
from scipy.stats import zscore

# %%
z= np.abs (zscore(data))
threshold=3 
np.where(z>3)
# Out:
# (array([  13,   14,   15,   15,   17,   17,   19,   33,   38,   42,   43,
#           45,   57,   81,   81,   83,   86,   88,   91,   92,   95,  106,
#          106,  109,  120,  126,  127,  142,  144,  147,  151,  151,  151,
#          151,  163,  164,  169,  169,  181,  199,  226,  226,  240,  243,
#          244,  258,  258,  274,  281,  291,  324,  325,  339,  340,  347,
#          354,  374,  381,  391,  396,  396,  400,  400,  442,  442,  451,
#          459,  467,  480,  480,  494,  515,  517,  544,  554,  554,  555,
#          555,  557,  557,  568,  584,  588,  591,  595,  608,  614,  636,
#          639,  649,  649,  651,  652,  652,  652,  672,  672,  684,  690,
#          690,  692,  692,  695,  723,  724,  730,  754,  776,  777,  795,
#          821,  832,  836,  837,  889,  899,  911,  917,  923,  925,  926,
#          982, 1017, 1018, 1043, 1051, 1051, 1071, 1074, 1079, 1079, 1081,
#         1081, 1111, 1114, 1131, 1154, 1165, 1175, 1186, 1231, 1235, 1244,
#         1244, 1244, 1260, 1269, 1269, 1270, 1270, 1288, 1289, 1295, 1296,
#         1299, 1299, 1300, 1312, 1316, 1319, 1319, 1321, 1358, 1367, 1370,
#         1370, 1372, 1372, 1374, 1374, 1434, 1434, 1434, 1435, 1435, 1435,
#         1469, 1474, 1474, 1474, 1476, 1476, 1476, 1478, 1493, 1496, 1505,
#         1558, 1558, 1570, 1574, 1589], dtype=int64),
#  array([ 9,  5,  5,  6,  4,  9,  4,  3,  1,  4,  9,  8,  5,  4,  9,  4,  9,
#          9,  9,  9,  8,  4,  9,  6,  1,  1,  1, 10, 10,  4,  2,  4,  8,  9,
#          3,  3,  4,  9,  4,  1,  4,  9,  4,  0,  0,  4,  9,  3,  4,  4,  3,
#          3,  9,  9,  0,  6,  0,  0,  0,  3,  5,  3,  5,  0,  7,  4, 11, 10,
#          3,  7,  3,  6, 11,  0,  0,  7,  0,  7,  0,  7,  4,  5, 10,  6,  3,
#          7,  9,  6,  9,  3,  6,  6,  0,  3, 10,  1,  6,  6,  1, 11,  4,  9,
#          8,  9,  1,  4,  4,  4,  4,  9, 10, 11,  7,  7,  7, 11,  3,  3,  3,
#          5,  5,  5,  7,  7,  3,  4,  9,  3,  3,  3,  6,  3,  6,  8,  7,  5,
#          5,  4,  5,  3,  5,  3,  3,  5,  6,  4,  7, 10,  7, 10,  9,  9,  5,
#          5,  1, 11,  8,  1,  8,  4,  9,  8,  5,  9,  4,  9,  4,  9,  4, 11,
#          3,  5,  7,  3,  5,  7, 11,  3,  5,  7,  3,  5,  7, 11,  6,  6, 11,
#          4,  5,  4,  3,  3], dtype=int64))

# %%
z.shape
# Out:
# (1599, 12)

# %%
data_new = data[(z<3).all(axis=1)]
print(data.shape)
print(data_new.shape)
# Out:
# (1599, 12)
# (1451, 12)

# %%
Loss_percentage=(1599-1451)/1599*100
print(Loss_percentage)
# Out:
# 9.255784865540964

# %%
wine_quality=[]
for i in data_new["quality"]:
    if i >=7:
        wine_quality.append(1)
    else:
        wine_quality.append(0)
data_new["Wine_catagory"]=wine_quality

# %% [markdown]
# dependent variable (wine quality) at e.g. 7 or higher getting classified as '1' and the remainder as '0'.

# %% [markdown]
# Now Remove skewness from data

# %%
from sklearn.preprocessing import power_transform

# %%
data_new.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
# 9                 17.0                 102.0   0.9978  3.35       0.80
#
#    alcohol  quality  Wine_catagory
# 0      9.4        5              0
# 1      9.8        5              0
# 2      9.8        5              0
# 3      9.8        6              0
# 4      9.4        5              0
# 5      9.4        5              0
# 6      9.4        5              0
# 7     10.0        7              1
# 8      9.5        7              1
# 9     10.5        5              0

# %% [markdown]
# Now split data in dependent and indipendent variable

# %%
X=data_new.iloc[:,0:-2]

# %%
Y=data_new.iloc[:,-1]

# %%
X.shape
# Out:
# (1451, 11)

# %%
Y.shape
# Out:
# (1451,)

# %%
X=power_transform(X,method='yeo-johnson')

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X=sc.fit_transform(X)
X
# Out:
# array([[-0.46787818,  1.05573967, -1.52450588, ...,  1.36086042,
#         -0.58965734, -1.12042399],
#        [-0.17080535,  1.91974976, -1.52450588, ..., -0.81650738,
#          0.45152416, -0.5303401 ],
#        [-0.17080535,  1.35706712, -1.24543379, ..., -0.38097654,
#          0.22000451, -0.5303401 ],
#        ...,
#        [-1.45100718, -0.00286664, -0.66625579, ...,  0.74685493,
#          0.93043194,  0.74288203],
#        [-1.88546393,  0.76651828, -0.72755539, ...,  1.76243705,
#          0.666655  , -0.03416625],
#        [-1.7722373 , -1.33320495,  1.07130142, ...,  0.53899166,
#          0.29909273,  0.74288203]])

# %% [markdown]
# Scaling tha data using StandardScaler for good model training.

# %%
sns.countplot(data_new['Wine_catagory'])
# Out:
# <AxesSubplot:xlabel='Wine_catagory', ylabel='count'>

# %%
data_new['Wine_catagory'].value_counts()
# Out:
# 0    1250
# 1     201
# Name: Wine_catagory, dtype: int64

# %% [markdown]
# Here we can see our output is not balanced we will now use SMOTE.

# %%
from imblearn.over_sampling import SMOTE

# %%
X_train_over, Y_train_over = SMOTE(k_neighbors=3).fit_resample(X,Y)

# %%
X_train_over
# Out:
# array([[-0.46787818,  1.05573967, -1.52450588, ...,  1.36086042,
#         -0.58965734, -1.12042399],
#        [-0.17080535,  1.91974976, -1.52450588, ..., -0.81650738,
#          0.45152416, -0.5303401 ],
#        [-0.17080535,  1.35706712, -1.24543379, ..., -0.38097654,
#          0.22000451, -0.5303401 ],
#        ...,
#        [ 1.68276525,  0.76923747,  1.67553018, ..., -0.79769906,
#          0.84297814,  1.87732981],
#        [ 0.92604574,  0.2555881 ,  0.46506791, ..., -0.38653597,
#          0.85974699,  1.33864346],
#        [-1.15491726,  1.73775408, -1.31385883, ...,  1.42821416,
#         -0.58965734,  1.59030982]])

# %%
Y_train_over.value_counts()
# Out:
# 0    1250
# 1    1250
# Name: Wine_catagory, dtype: int64

# %%
Y_train_over.value_counts()
# Out:
# 0    1250
# 1    1250
# Name: Wine_catagory, dtype: int64

# %%
sns.countplot(Y_train_over)
# Out:
# <AxesSubplot:xlabel='Wine_catagory', ylabel='count'>

# %%
Xtrain=pd.DataFrame(data=X_train_over, columns=data.columns[0:11])
Xtrain
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.467878          1.055740    -1.524506       -0.610683  -0.145035
# 1         -0.170805          1.919750    -1.524506        0.649155   0.986838
# 2         -0.170805          1.357067    -1.245434        0.207601   0.718578
# 3          1.573404         -1.556675     1.444056       -0.610683  -0.207213
# 4         -0.467878          1.055740    -1.524506       -0.610683  -0.145035
# ...             ...               ...          ...             ...        ...
# 2495       0.633492         -1.438911     0.455209       -0.327832  -0.999235
# 2496      -0.242536          0.407253    -1.453374       -0.872634   0.524093
# 2497       1.682765          0.769237     1.675530        1.910640   0.966422
# 2498       0.926046          0.255588     0.465068        0.412243   0.354903
# 2499      -1.154917          1.737754    -1.313859        0.207601  -1.362067
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0               -0.241492             -0.066536  0.640791  1.360860
# 1                1.091561              0.952517  0.061011 -0.816507
# 2                0.238587              0.624244  0.177435 -0.380977
# 3                0.440493              0.784119  0.756049 -1.110847
# 4               -0.241492             -0.066536  0.640791  1.360860
# ...                   ...                   ...       ...       ...
# 2495            -0.056820             -0.466797 -0.902556 -0.380977
# 2496            -0.109754             -0.982054 -0.595310  0.047571
# 2497            -1.021805             -0.856788  1.293882 -0.797699
# 2498             1.641134              0.909509  0.162028 -0.386536
# 2499             1.530980              0.446604 -0.878864  1.428214
#
#       sulphates   alcohol
# 0     -0.589657 -1.120424
# 1      0.451524 -0.530340
# 2      0.220005 -0.530340
# 3     -0.393177 -0.530340
# 4     -0.589657 -1.120424
# ...         ...       ...
# 2495   1.441319  1.249254
# 2496  -0.589657  0.287037
# 2497   0.842978  1.877330
# 2498   0.859747  1.338643
# 2499  -0.589657  1.590310
#
# [2500 rows x 11 columns]

# %%
Ytrain=pd.DataFrame(data=Y_train_over)
Ytrain
# Out:
#       Wine_catagory
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 2495              1
# 2496              1
# 2497              1
# 2498              1
# 2499              1
#
# [2500 rows x 1 columns]

# %% [markdown]
# As we can see VIF is less than 10 we will not remove any columns, and proceed further.
#
# Since our output is having only two values "0" and "1", we will use binary classification model.

# %%
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix 

lr=LogisticRegression()

# %%
for i in range(0,1000):
    X_train, X_test, Y_train, Y_test = train_test_split(Xtrain,Ytrain,random_state= i, test_size=.20)
    lr.fit(X_train,Y_train)
    pred_train= lr.predict(X_train)
    pred_test=lr.predict(X_test)
    if round(accuracy_score(Y_train, pred_train)*100,1)== round(accuracy_score(Y_test, pred_test)*100,1):
        print("At Random state",i, "The model perform very well")
        print("At random State:",i)
        print("Training r2_score",accuracy_score(Y_train,pred_train)*100)
        print("testing r2 score ",accuracy_score(Y_test,pred_test)*100)
# Out:
# At Random state 4 The model perform very well
# At random State: 4
# Training r2_score 82.65
# testing r2 score  82.6
# At Random state 49 The model perform very well
# At random State: 49
# Training r2_score 82.05
# testing r2 score  82.0
# At Random state 52 The model perform very well
# At random State: 52
# Training r2_score 82.15
# testing r2 score  82.19999999999999
# At Random state 60 The model perform very well
# At random State: 60
# Training r2_score 82.39999999999999
# testing r2 score  82.39999999999999
# At Random state 71 The model perform very well
# At random State: 71
# Training r2_score 82.39999999999999
# testing r2 score  82.39999999999999
# At Random state 93 The model perform very well
# At random State: 93
# Training r2_score 82.39999999999999
# testing r2 score  82.39999999999999
# At Random state 168 The model perform very well
# At random State: 168
# Training r2_score 82.05
# testing r2 score  82.0
# At Random state 173 The model perform very well
# At random State: 173
# Training r2_score 82.19999999999999
# testing r2 score  82.19999999999999
# At Random state 176 The model perform very well
# At random State: 176
# Training r2_score 82.8
# testing r2 score  82.8
# At Random state 182 The model perform very well
# At random State: 182
# Training r2_score 82.39999999999999
# testing r2 score  82.39999999999999
# At Random state 241 The model perform very well
# At random State: 241
# Training r2_score 82.45
# testing r2 score  82.39999999999999
# At Random state 333 The model perform very well
# At random State: 333
# Training r2_score 82.19999999999999
# testing r2 score  82.19999999999999
# At Random state 368 The model perform very well
# At random State: 368
# Training r2_score 82.05
# testing r2 score  82.0
# At Random state 397 The model perform very well
# At random State: 397
# Training r2_score 82.19999999999999
# testing r2 score  82.19999999999999
# At Random state 439 The model perform very well
# At random State: 439
# Training r2_score 82.25
# testing r2 score  82.19999999999999
# At Random state 491 The model perform very well
# At random State: 491
# Training r2_score 82.25
# testing r2 score  82.19999999999999
# At Random state 505 The model perform very well
# At random State: 505
# Training r2_score 82.19999999999999
# testing r2 score  82.19999999999999
# At Random state 586 The model perform very well
# At random State: 586
# Training r2_score 82.05
# testing r2 score  82.0
# At Random state 686 The model perform very well
# At random State: 686
# Training r2_score 82.39999999999999
# testing r2 score  82.39999999999999
# At Random state 707 The model perform very well
# At random State: 707
# Training r2_score 82.55
# testing r2 score  82.6
# At Random state 714 The model perform very well
# At random State: 714
# Training r2_score 82.0
# testing r2 score  82.0
# At Random state 771 The model perform very well
# At random State: 771
# Training r2_score 82.19999999999999
# testing r2 score  82.19999999999999
# At Random state 792 The model perform very well
# At random State: 792
# Training r2_score 82.35
# testing r2 score  82.39999999999999
# At Random state 822 The model perform very well
# At random State: 822
# Training r2_score 82.6
# testing r2 score  82.6
# At Random state 841 The model perform very well
# At random State: 841
# Training r2_score 82.15
# testing r2 score  82.19999999999999
# At Random state 842 The model perform very well
# At random State: 842
# Training r2_score 82.65
# testing r2 score  82.6
# At Random state 858 The model perform very well
# At random State: 858
# Training r2_score 82.0
# testing r2 score  82.0
# At Random state 885 The model perform very well
# At random State: 885
# Training r2_score 82.39999999999999
# testing r2 score  82.39999999999999
# At Random state 890 The model perform very well
# At random State: 890
# Training r2_score 82.6
# testing r2 score  82.6
# At Random state 907 The model perform very well
# At random State: 907
# Training r2_score 82.19999999999999
# testing r2 score  82.19999999999999
# At Random state 940 The model perform very well
# At random State: 940
# Training r2_score 82.39999999999999
# testing r2 score  82.39999999999999
# At Random state 969 The model perform very well
# At random State: 969
# Training r2_score 82.39999999999999
# testing r2 score  82.39999999999999
# At Random state 976 The model perform very well
# At random State: 976
# Training r2_score 82.19999999999999
# testing r2 score  82.19999999999999
# At Random state 977 The model perform very well
# At random State: 977
# Training r2_score 82.65
# testing r2 score  82.6

# %%
X_train, X_test, Y_train, Y_test= train_test_split(Xtrain,Ytrain,random_state=929,test_size=0.20)

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.38      0.43       252
#            1       0.48      0.58      0.52       248
#
#     accuracy                           0.48       500
#    macro avg       0.48      0.48      0.48       500
# weighted avg       0.48      0.48      0.48       500

# %%
pred_lr = lr.predict(X_test)
from sklearn.model_selection import cross_val_score
lss=accuracy_score(Y_test,pred_lr)
for j in range(2,10):
    lsscore= cross_val_score(lr,Xtrain,Ytrain,cv=j)
    lsc=lsscore.mean()
    print("at cv:-", j)
    print("Cross Validation scre is:-",lsc*100)
    print("Accuracy Score:-", lss*100)
    print("\n")
# Out:
# at cv:- 2
# Cross Validation scre is:- 78.72
# Accuracy Score:- 79.60000000000001
#
#
# at cv:- 3
# Cross Validation scre is:- 80.47871426748158
# Accuracy Score:- 79.60000000000001
#
#
# at cv:- 4
# Cross Validation scre is:- 80.48
# Accuracy Score:- 79.60000000000001
#
#
# at cv:- 5
# Cross Validation scre is:- 80.11999999999999
# Accuracy Score:- 79.60000000000001
#
#
# at cv:- 6
# Cross Validation scre is:- 80.3582134292566
# Accuracy Score:- 79.60000000000001
#
#
# at cv:- 7
# Cross Validation scre is:- 80.3962925952504
# Accuracy Score:- 79.60000000000001
#
#
# at cv:- 8
# Cross Validation scre is:- 80.59348631932497
# Accuracy Score:- 79.60000000000001
#
#
# at cv:- 9
# Cross Validation scre is:- 80.96093522294079
# Accuracy Score:- 79.60000000000001

# %%
lssscore_selected=cross_val_score(lr,Xtrain,Ytrain,cv=9).mean()
print("The cv score is: ", lssscore_selected,"\nThe accuracy score is: ", lss)
# Out:
# The cv score is:  0.8096093522294079
# The accuracy score is:  0.796

# %%
rfcv=RandomForestClassifier()
rfcv.fit(X_train, Y_train)
rfcv.score(X_train,Y_train)
rfpred=rfcv.predict(X_test)

print (accuracy_score(Y_test,rfpred))
print (confusion_matrix(Y_test,rfpred))
print (classification_report(Y_test,rfpred))
print('\n')
# Out:
# 0.95
# [[236  16]
#  [  9 239]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       252
#            1       0.94      0.96      0.95       248
#
#     accuracy                           0.95       500
#    macro avg       0.95      0.95      0.95       500
# weighted avg       0.95      0.95      0.95       500

# %%
RFA=accuracy_score(Y_test,rfpred)
RFcv=cross_val_score(rfcv,Xtrain,Ytrain,cv=9).mean()
print("The cv score is: ", RFcv,"\nThe accuracy score is: ", RFA)
# Out:
# The cv score is:  0.9363931237681337
# The accuracy score is:  0.95

# %%
gbcv=GaussianNB()
gbcv.fit(X_train, Y_train)
gbcv.score(X_train,Y_train)
gbpred=gbcv.predict(X_test)

print (accuracy_score(Y_test,gbpred))
print (confusion_matrix(Y_test,gbpred))
print (classification_report(Y_test,gbpred))
print('\n')
# Out:
# 0.794
# [[197  55]
#  [ 48 200]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.78      0.79       252
#            1       0.78      0.81      0.80       248
#
#     accuracy                           0.79       500
#    macro avg       0.79      0.79      0.79       500
# weighted avg       0.79      0.79      0.79       500

# %%
GBA=accuracy_score(Y_test,rfpred)
GBcv=cross_val_score(gbcv,Xtrain,Ytrain,cv=9).mean()
print("The cv score is: ", GBcv,"\nThe accuracy score is: ", GBA)
# Out:
# The cv score is:  0.7976160587775267
# The accuracy score is:  0.95

# %%
kccv=KNeighborsClassifier()
kccv.fit(X_train, Y_train)
kccv.score(X_train,Y_train)
kcpred=kccv.predict(X_test)

print (accuracy_score(Y_test,kcpred))
print (confusion_matrix(Y_test,kcpred))
print (classification_report(Y_test,kcpred))
print('\n')
# Out:
# 0.892
# [[199  53]
#  [  1 247]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.79      0.88       252
#            1       0.82      1.00      0.90       248
#
#     accuracy                           0.89       500
#    macro avg       0.91      0.89      0.89       500
# weighted avg       0.91      0.89      0.89       500

# %%
KCA=accuracy_score(Y_test,kcpred)
KCcv=cross_val_score(kccv,Xtrain,Ytrain,cv=9).mean()
print("The cv score is: ", KCcv,"\nThe accuracy score is: ", KCA)
# Out:
# The cv score is:  0.8647681133071882
# The accuracy score is:  0.892

# %%
dtcv=DecisionTreeClassifier()
dtcv.fit(X_train, Y_train)
dtcv.score(X_train,Y_train)
dtpred=dtcv.predict(X_test)

print (accuracy_score(Y_test,dtpred))
print (confusion_matrix(Y_test,dtpred))
print (classification_report(Y_test,dtpred))
print('\n')
# Out:
# 0.938
# [[230  22]
#  [  9 239]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.94       252
#            1       0.92      0.96      0.94       248
#
#     accuracy                           0.94       500
#    macro avg       0.94      0.94      0.94       500
# weighted avg       0.94      0.94      0.94       500

# %%
DTA=accuracy_score(Y_test,dtpred)
DTcv=cross_val_score(kccv,Xtrain,Ytrain,cv=9).mean()
print("The cv score is: ", KCcv,"\nThe accuracy score is: ", KCA)
# Out:
# The cv score is:  0.8647681133071882
# The accuracy score is:  0.892

# %%
Model= [LogisticRegression(),RandomForestClassifier(),GaussianNB(),KNeighborsClassifier(),DecisionTreeClassifier(), SVC()]

for m in Model:
    m.fit(X_train,Y_train)
    m.score(X_train,Y_train)
    predm=m.predict(X_test)
    print('Accuracy score of', m, 'is:')
    print (accuracy_score(Y_test,predm))
    print (confusion_matrix(Y_test,predm))
    print (classification_report(Y_test,predm))
    print('\n')
# Out:
# Accuracy score of LogisticRegression() is:
# 0.804
# [[199  53]
#  [ 45 203]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.79      0.80       252
#            1       0.79      0.82      0.81       248
#
#     accuracy                           0.80       500
#    macro avg       0.80      0.80      0.80       500
# weighted avg       0.80      0.80      0.80       500
#
#
#
# Accuracy score of RandomForestClassifier() is:
# 0.952
# [[237  15]
#  [  9 239]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       252
#            1       0.94      0.96      0.95       248
#
#     accuracy                           0.95       500
#    macro avg       0.95      0.95      0.95       500
# weighted avg       0.95      0.95      0.95       500
#
#
#
# Accuracy score of GaussianNB() is:
# 0.794
# [[197  55]
#  [ 48 200]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.78      0.79       252
#            1       0.78      0.81      0.80       248
#
#     accuracy                           0.79       500
#    macro avg       0.79      0.79      0.79       500
# weighted avg       0.79      0.79      0.79       500
#
#
#
# Accuracy score of KNeighborsClassifier() is:
# 0.892
# [[199  53]
#  [  1 247]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.79      0.88       252
#            1       0.82      1.00      0.90       248
#
#     accuracy                           0.89       500
#    macro avg       0.91      0.89      0.89       500
# weighted avg       0.91      0.89      0.89       500
#
#
#
# Accuracy score of DecisionTreeClassifier() is:
# 0.94
# [[231  21]
#  [  9 239]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94       252
#            1       0.92      0.96      0.94       248
#
#     accuracy                           0.94       500
#    macro avg       0.94      0.94      0.94       500
# weighted avg       0.94      0.94      0.94       500
#
#
#
# Accuracy score of SVC() is:
# 0.874
# [[210  42]
#  [ 21 227]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.83      0.87       252
#            1       0.84      0.92      0.88       248
#
#     accuracy                           0.87       500
#    macro avg       0.88      0.87      0.87       500
# weighted avg       0.88      0.87      0.87       500

# %% [markdown]
# # Now check accuracy usig Hyperparameter tuning: GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters= {'n_estimators' : [20, 40, 60, 80, 100,120, 140,160, 200], 'criterion':['gini', 'entropy'], 'bootstrap':[0,1,0,1,0,1]}
model=RandomForestClassifier()
Grid= GridSearchCV(estimator=model, param_grid= parameters)
Grid.fit(X_train, Y_train)


print(Grid)
print(Grid.best_score_)

print(Grid.best_params_)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [0, 1, 0, 1, 0, 1],
#                          'criterion': ['gini', 'entropy'],
#                          'n_estimators': [20, 40, 60, 80, 100, 120, 140, 160,
#                                           200]})
# 0.953
# {'bootstrap': 0, 'criterion': 'entropy', 'n_estimators': 120}

# %%
p=Grid.predict(X_test)

print (accuracy_score(Y_test,p))
print (confusion_matrix(Y_test,p))
print (classification_report(Y_test,p))
print('\n')
# Out:
# 0.956
# [[237  15]
#  [  7 241]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96       252
#            1       0.94      0.97      0.96       248
#
#     accuracy                           0.96       500
#    macro avg       0.96      0.96      0.96       500
# weighted avg       0.96      0.96      0.96       500

# %%
RF=RandomForestClassifier()
RF.fit(X_train,Y_train)
RF.score(X_train,Y_train)

RFpred=RF.predict(X_test)
print(accuracy_score(Y_test,RFpred ))
print(confusion_matrix(Y_test,RFpred ))
print(classification_report(Y_test,RFpred ))
# Out:
# 0.95
# [[236  16]
#  [  9 239]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       252
#            1       0.94      0.96      0.95       248
#
#     accuracy                           0.95       500
#    macro avg       0.95      0.95      0.95       500
# weighted avg       0.95      0.95      0.95       500

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds= roc_curve(p, Y_test)
roc_auc= auc(fpr, tpr)

plt.figure()
plt.plot(fpr,tpr, color='darkorange', lw=10,label='ROC curve (area= %0.2f)' %roc_auc)
plt.plot([0,1],[0,1],color ='navy', lw=10, linestyle= '--')
plt.xlim([0.0, 1.0])
plt.xlim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# AOC-ROC Curve
#
# Now Save Best Model

# %%
import pickle
filename='Quality_of_Red_wine_Prediction.pkl'
pickle.dump(RF,open(filename,'wb'))
